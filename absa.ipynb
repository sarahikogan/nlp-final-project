# %% [markdown]
# ABSA Plan:
#
# - 5 key sentiments: Location, service, quality, atmosphere, value
# - Rate each review on sentiment toward each of these topics
# - Rate each review on strength of that sentiment in the review (maybe)
# - For a business, summarize overall sentiment toward each of these aspects
#     - Pull out positive or negative aspects of reviews

# %%
import spacy
import pandas as pd
import numpy as np
import textblob
from textblob import TextBlob
import math 
import matplotlib.pyplot as plt

sp = spacy.load('en_core_web_md')

# %% [markdown]
# #### Load datasets:

# %%
# original dataset, sampled
df = pd.read_csv('reviews_with_parents.csv')

# %%
# tokenized dataset
df = pd.read_csv('yelp_processed_v3.csv')

# turn tokens back into arrays
import ast
df['text'] = df['text'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)

if (type(df['text'][0] != 'text')): df['text'] = df['text'].apply(lambda x: ' '.join(x))

# %%
df = pd.read_csv('yelp_processed_v4.csv')
df = df[:500]

# %%
df.head()
# Out:
#    Unnamed: 0               review_id                 user_id  \
# 0           0  KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA
# 1           1  BiTunyQ73aT9WBnpR9DZGw  OyoGAe7OKpv6SyGZT5g77Q
# 2           2  saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A
# 3           3  AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ
# 4           4  Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ
#
#               business_id  stars  useful  funny  cool  \
# 0  XQfwVwDr-v0ZS3_CbbE5Xw    3.0       0      0     0
# 1  7ATYjTIgM3jUlt4UM3IypQ    5.0       1      0     1
# 2  YjUWPpI6HXG530lwP-fb2A    3.0       0      0     0
# 3  kxX2SOes4o-D3ZQBkiMRfA    5.0       1      0     1
# 4  e4Vwtrqf-wpJfwesgvdgxQ    4.0       1      0     1
#
#                                                 text                 date  \
# 0  If you decide to eat here, just be aware it is...  2018-07-07 22:09:11
# 1  I've taken a lot of spin classes over the year...  2012-01-03 15:28:18
# 2  Family diner. Had the buffet. Eclectic assortm...  2014-02-05 20:30:30
# 3  Wow!  Yummy, different,  delicious.   Our favo...  2015-01-04 00:01:03
# 4  Cute interior and owner (?) gave us tour of up...  2017-01-14 20:54:15
#
#         category
# 0           food
# 1  entertainment
# 2           food
# 3           food
# 4           food

# %% [markdown]
# #### Model Architecture
#
# Input: Reviews
#
# Output: Binary output for each sentiment category (sigmoid)
#
# Loss: BCE
#
# Optim: Adam

# %% [markdown]
# If you decide to eat here, just be aware it is going to take about 2 hours from beginning to end.
#
# We have tried it multiple times, because I want to like it!
#
# I have been to it's other locations in NJ and never had a bad experience.
#
# The food is good, but it takes a very long time to come out.
#
# The waitstaff is very young, but usually pleasant.
#
# We have just had too many experiences where we spent way too long waiting.
#
# We usually opt for another diner or restaurant on the weekends, in order to be done quicker.

# %% [markdown]
# #### Calculate aspect-based sentiments

# %%
def get_similar_words(topics, vocab_doc, threshold=0.55):
    words_dict = {}
    for topic in topics: 
        topic_token = sp(topic)
        similar_words = set()
        
        # compare with words in vocabulary
        for word in vocab_doc: 
            if word.has_vector and word.is_alpha: 
                similarity = topic_token.similarity(word)
                if similarity > threshold: 
                    similar_words.add((word.text.lower(), similarity))

        # sort by similarity score
        similar_words = sorted(similar_words, key=lambda x: x[1], reverse=True)# [:n] 
        words_dict[topic] = [word[0] for word in similar_words] 
    
    return words_dict

# %%
# set topics
topics = ['location', 'service', 'quality', 'atmosphere', 'value']

# set vocab
vocab_doc = " ".join([w for w in df['text']])
vocab_doc = " ".join(set(vocab_doc.split()))
vocab_doc = sp(vocab_doc)

# get similar words
similar_words = get_similar_words(topics, vocab_doc, threshold=0.55)
print(similar_words)
# Out:
# {'location': ['location', 'accurately', 'exact', 'verify', 'readings', 'precisely', 'gauges', 'correct', 'detailed', 'consistent', 'precision', 'pinpoint', 'accurate', 'timing', 'location', 'precise', 'timely', 'gauge', 'locate', 'dated', 'inaccurate', 'incorrect', 'questionable'], 'service': ['service', 'service', 'ordering', 'options', 'pricing', 'specifications', 'details', 'bundle', 'availability', 'cart', 'bought', 'pack', 'price', 'item', 'value', 'purchased', 'buying', 'order', 'shipping', 'priced', 'shops', 'prices', 'option', 'save', 'supplies', 'upgrades', 'plan', 'delivery', 'available', 'anywhere', 'bungalow', 'purchasing', 'cost', 'plans', 'for', 'cheaper', 'replacement', 'package', 'accommodations', 'travelers', 'reservations', 'vary', 'motels', 'destinations', 'rental', 'occupancy', 'rates', 'lodging', 'rooms', 'transportation', 'domestic', 'savings', 'burden', 'budget', 'costs', 'freight', 'warehouse', 'buyers', 'stores', 'franchises', 'showroom', 'consumer', 'dealer', 'sells', 'marketing', 'shoppers', 'outlets', 'brands', 'retailing', 'sell', 'sales', 'leasing', 'sold', 'retailers', 'company', 'inventory', 'retailer', 'commercial', 'new', 'dealership', 'customers', 'merchandising', 'selling', 'owner', 'department', 'franchise', 'chain', 'retail', 'merchandise'], 'quality': ['quality', 'superb', 'fits', 'quality', 'best', 'our', 'original', 'custom', 'wide', 'fit', 'manufacturer', 'style', 'outstanding', 'offers', 'accessories', 'specialize', 'perfect', 'offering', 'full', 'design', 'finest', 'factory', 'choice', 'frames', 'brand', 'conservatory', 'selection', 'superlative', 'boasts', 'boast', 'exceptional', 'comforts', 'ultimate', 'affords', 'renovated', 'qualities', 'supreme', 'luxurious', 'delivers', 'unsurpassed', 'unbeatable', 'comfort', 'furnished', 'superior', 'retaining', 'advanced', 'amenities', 'notch', 'unmatched', 'excels', 'highest', 'premier', 'among', 'pinnacle', 'destination', 'newest', 'peak', 'peaks', 'fastest', 'national', 'widest', 'ascent', 'nationally', 'surpass', 'tallest', 'representing', 'insure', 'assure', 'promise', 'provide', 'backed', 'secure', 'offer', 'ensure', 'lifetime', 'avail', 'complete', 'assures', 'fully', 'ensured', 'ensuring', 'guaranteed', 'ensures', 'guarantee', 'warranties', 'assured', 'warranty'], 'atmosphere': ['atmosphere', 'alternated', 'vibrant', 'beginning', 'intensive', 'enduring', 'lasting', 'lingering', 'attraction', 'encounter', 'intense', 'jolt', 'immersed', 'vivid', 'searing', 'anticipation', 'dark', 'passion', 'atmosphere', 'session', 'blazing', 'energetic', 'fiery', 'strenuous', 'dramatic', 'paced', 'intensely', 'backdrop', 'sensation', 'blinding', 'grueling', 'concentrated', 'captures', 'deep', 'excitement', 'intimate', 'icy', 'heated', 'experiencing', 'subtle', 'hectic', 'intensity', 'brisk', 'warmth', 'hiking', 'skiing', 'extreme', 'frigid', 'ultra', 'ski', 'arctic', 'cycling', 'snow', 'terrain', 'endurance', 'harrowing', 'sweltering', 'stark', 'grisly', 'brutally', 'crushing', 'grim', 'chilling', 'bloody', 'brutal', 'bleak', 'forced', 'completely', 'specially', 'totally', 'super', 'fairly', 'secluded', 'quite', 'indeed', 'so', 'became', 'is', 'beautiful', 'spacious', 'familiar', 'unusual', 'very', 'popular', 'more', 'exceptionally', 'often', 'highly', 'suited', 'especially', 'extremely', 'these', 'extraordinarily', 'elegant', 'wonderfully', 'rare', 'typically', 'generally', 'beautifully', 'aware', 'attractive', 'equally', 'remain', 'visually', 'uniquely', 'dense', 'importantly', 'both', 'pretty', 'makes', 'many', 'pleased', 'undoubtedly', 'small', 'charming', 'also', 'exceedingly', 'surroundings', 'yet', 'handy', 'versatile', 'unique', 'extremly', 'usually', 'being', 'short', 'comfortable', 'excellent', 'as', 'well', 'deeply', 'varied', 'impressed', 'outstandingly', 'talented', 'reasonably', 'extrememly', 'consistently', 'most', 'remains', 'definitely', 'particularly', 'plenty', 'amazingly', 'truly', 'pleasing', 'fascinated', 'demanding', 'thoroughly' ...

# %%
# 0.55: highest threshold without significant loss
def extract_topic_sentiment(text, topics, similar_words, threshold=0.55): 
    doc = sp(text)
    # sentiment score for extracted sentence
    sentiment_scores = {}

    for topic in topics:

        # sentences for now, TODO make it phrases later 
        topic_sentences = [sent.text for sent in doc.sents if any(word in sent.text.lower() for word in similar_words[topic])]

        topic_sentiments = []
        for sentence in topic_sentences: 
            blob = TextBlob(sentence)
            topic_sentiments.append(blob.sentiment.polarity)

        # average sentiments for each topic
        if topic_sentiments: 
            sentiment_scores[topic] = (sum(topic_sentiments) / len(topic_sentiments))
        else: 
            sentiment_scores[topic] = None

    # print(sentiment_scores)
        
    # if there is not a score for each sentiment, average all sentiments and set that to the score
    blob = TextBlob(text)
    avg_sentiment = blob.sentiment.polarity

    # print([s for s in sentiment_scores])

    for s in sentiment_scores: 
        if sentiment_scores[s] is None: 
            sentiment_scores[s] = avg_sentiment

    sentiment_scores['overall'] = avg_sentiment
    return sentiment_scores
        
sample_text = 'If you decide to eat here, just be aware it is going to take about 2 hours from beginning to end. We have tried it multiple times, because I want to like it! I have been to its other locations in NJ and never had a bad experience. The food is good, but it takes a very long time to come out. The waitstaff is very young, but usually pleasant. We have just had too many experiences where we spent way too long waiting. We usually opt for another diner or restaurant on the weekends, in order to be done quicker.'
        
sentiment_scores = extract_topic_sentiment('Wow! Yummy, different, delicious. Our favo...	', topics, similar_words, threshold=0.55)

# %%
print(sentiment_scores)
# Out:
# {'location': 0.375, 'service': 0.375, 'quality': 0.0, 'atmosphere': 0.0, 'value': 0.375, 'overall': 0.375}

# %%
def add_topic_cols(df, sentiment_scores):
    for topic in sentiment_scores.keys(): 
        df[topic] = None
    return df

# %%
df = df.drop(['location', 'service', 'quality', 'atmosphere', 'value', 'overall'], axis=1)

# %%
df.head()
# Out:
#    Unnamed: 0               review_id                 user_id  \
# 0           0  KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA
# 1           1  BiTunyQ73aT9WBnpR9DZGw  OyoGAe7OKpv6SyGZT5g77Q
# 2           2  saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A
# 3           3  AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ
# 4           4  Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ
#
#               business_id  stars  useful  funny  cool  \
# 0  XQfwVwDr-v0ZS3_CbbE5Xw    3.0       0      0     0
# 1  7ATYjTIgM3jUlt4UM3IypQ    5.0       1      0     1
# 2  YjUWPpI6HXG530lwP-fb2A    3.0       0      0     0
# 3  kxX2SOes4o-D3ZQBkiMRfA    5.0       1      0     1
# 4  e4Vwtrqf-wpJfwesgvdgxQ    4.0       1      0     1
#
#                                                 text                 date  \
# 0  If you decide to eat here, just be aware it is...  2018-07-07 22:09:11
# 1  I've taken a lot of spin classes over the year...  2012-01-03 15:28:18
# 2  Family diner. Had the buffet. Eclectic assortm...  2014-02-05 20:30:30
# 3  Wow!  Yummy, different,  delicious.   Our favo...  2015-01-04 00:01:03
# 4  Cute interior and owner (?) gave us tour of up...  2017-01-14 20:54:15
#
#         category
# 0           food
# 1  entertainment
# 2           food
# 3           food
# 4           food

# %%
# get topic sentiments for each review 
sentiments = df['text'].apply(lambda x: extract_topic_sentiment(x, topics, similar_words))

# %%
# convert sentiments to df 
sentiment_df = pd.DataFrame.from_dict(sentiments)
sentiment_df = pd.json_normalize(sentiments)

df = pd.concat([df, sentiment_df], axis=1)

# %%
df.head()
# Out:
#    Unnamed: 0               review_id                 user_id  \
# 0           0  KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA
# 1           1  BiTunyQ73aT9WBnpR9DZGw  OyoGAe7OKpv6SyGZT5g77Q
# 2           2  saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A
# 3           3  AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ
# 4           4  Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ
#
#               business_id  stars  useful  funny  cool  \
# 0  XQfwVwDr-v0ZS3_CbbE5Xw    3.0       0      0     0
# 1  7ATYjTIgM3jUlt4UM3IypQ    5.0       1      0     1
# 2  YjUWPpI6HXG530lwP-fb2A    3.0       0      0     0
# 3  kxX2SOes4o-D3ZQBkiMRfA    5.0       1      0     1
# 4  e4Vwtrqf-wpJfwesgvdgxQ    4.0       1      0     1
#
#                                                 text                 date  \
# 0  If you decide to eat here, just be aware it is...  2018-07-07 22:09:11
# 1  I've taken a lot of spin classes over the year...  2012-01-03 15:28:18
# 2  Family diner. Had the buffet. Eclectic assortm...  2014-02-05 20:30:30
# 3  Wow!  Yummy, different,  delicious.   Our favo...  2015-01-04 00:01:03
# 4  Cute interior and owner (?) gave us tour of up...  2017-01-14 20:54:15
#
#         category  location   service   quality  atmosphere     value   overall
# 0           food -0.412500 -0.250000  0.250000    0.064762 -0.250000  0.085278
# 1  entertainment  0.402273  0.264583  0.315000    0.225000  0.227778  0.402273
# 2           food  0.139935  0.100000  0.000000    0.123214  0.050000  0.139935
# 3           food  0.302557  0.085227  0.292614    0.302557  0.085227  0.302557
# 4           food  0.400969  0.491667  0.716667    0.253267  0.133333  0.400969

# %%
df.to_csv('df_withsentiments.csv')

# %% [markdown]
# #### Add names of businesses to dataframe

# %%
reviews_df = pd.read_csv('df_withsentiments.csv')
bus_df = pd.read_csv('yelp_businesses.csv')

# %%
bus_df.head()
# Out:
#    Unnamed: 0             business_id                      name  \
# 0           0  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1           1  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2           2  tUFrWirKiKi_TAnsVWINQQ                    Target
# 3           3  MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4           4  mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
#
#                            address           city state postal_code  \
# 0           1616 Chapala St, Ste 2  Santa Barbara    CA       93101
# 1  87 Grasso Plaza Shopping Center         Affton    MO       63123
# 2             5255 E Broadway Blvd         Tucson    AZ       85711
# 3                      935 Race St   Philadelphia    PA       19107
# 4                    101 Walnut St     Green Lane    PA       18054
#
#     latitude   longitude  stars  review_count  is_open  \
# 0  34.426679 -119.711197    5.0             7        0
# 1  38.551126  -90.335695    3.0            15        1
# 2  32.223236 -110.880452    3.5            22        0
# 3  39.955505  -75.155564    4.0            80        1
# 4  40.338183  -75.471659    4.5            13        1
#
#                                           attributes  \
# 0                      {'ByAppointmentOnly': 'True'}
# 1             {'BusinessAcceptsCreditCards': 'True'}
# 2  {'BikeParking': 'True', 'BusinessAcceptsCredit...
# 3  {'RestaurantsDelivery': 'False', 'OutdoorSeati...
# 4  {'BusinessAcceptsCreditCards': 'True', 'Wheelc...
#
#                                           categories  \
# 0  Doctors, Traditional Chinese Medicine, Naturop...
# 1  Shipping Centers, Local Services, Notaries, Ma...
# 2  Department Stores, Shopping, Fashion, Home & G...
# 3  Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# 4                          Brewpubs, Breweries, Food
#
#                                                hours
# 0                                                NaN
# 1  {'Monday': '0:0-0:0', 'Tuesday': '8:0-18:30', ...
# 2  {'Monday': '8:0-22:0', 'Tuesday': '8:0-22:0', ...
# 3  {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...
# 4  {'Wednesday': '14:0-22:0', 'Thursday': '16:0-2...

# %%
merged_df = reviews_df.merge(bus_df[['business_id', 'name', 'address', 'city', 'state', 'postal_code', 'latitude', 'longitude', 'review_count']],
                             on = 'business_id',
                             how='left')

# %%
merged_df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0               review_id                 user_id  \
# 0             0           0  KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA
# 1             1           1  BiTunyQ73aT9WBnpR9DZGw  OyoGAe7OKpv6SyGZT5g77Q
# 2             2           2  saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A
# 3             3           3  AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ
# 4             4           4  Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ
#
#               business_id  stars  useful  funny  cool  \
# 0  XQfwVwDr-v0ZS3_CbbE5Xw    3.0       0      0     0
# 1  7ATYjTIgM3jUlt4UM3IypQ    5.0       1      0     1
# 2  YjUWPpI6HXG530lwP-fb2A    3.0       0      0     0
# 3  kxX2SOes4o-D3ZQBkiMRfA    5.0       1      0     1
# 4  e4Vwtrqf-wpJfwesgvdgxQ    4.0       1      0     1
#
#                                                 text  ...     value   overall  \
# 0  If you decide to eat here, just be aware it is...  ... -0.250000  0.085278
# 1  I've taken a lot of spin classes over the year...  ...  0.227778  0.402273
# 2  Family diner. Had the buffet. Eclectic assortm...  ...  0.050000  0.139935
# 3  Wow!  Yummy, different,  delicious.   Our favo...  ...  0.085227  0.302557
# 4  Cute interior and owner (?) gave us tour of up...  ...  0.133333  0.400969
#
#                            name                   address          city  \
# 0  Turning Point of North Wales       1460 Bethlehem Pike   North Wales
# 1    Body Cycle Spinning Studio  1923 Chestnut St, 2nd Fl  Philadelphia
# 2             Kettle Restaurant     748 W Starr Pass Blvd        Tucson
# 3                         Zaika            2481 Grant Ave  Philadelphia
# 4                          Melt             2549 Banks St   New Orleans
#
#    state  postal_code   latitude   longitude review_count
# 0     PA        19454  40.210196  -75.223639          169
# 1     PA        19119  39.952103  -75.172753          144
# 2     AZ        85713  32.207233 -110.980864           47
# 3     PA        19114  40.079848  -75.025080          181
# 4     LA        70119  29.962102  -90.087958           32
#
# [5 rows x 26 columns]

# %%
merged_df.to_csv('reviews_wpars_wsents_wbusinfo.csv')
